# %%
# Importing pandas
import pandas as pd
import matplotlib.pyplot as plt

# SQL Alchemy
from sqlalchemy import create_engine

# Defining path to database
engine = create_engine("postgres://postgres:1234@localhost:5432/employees")
conn = engine.connect()

# %%
# Creating dataframes of the relevent tables
employees_data = pd.read_sql("SELECT * FROM employees", conn)
salary_data = pd.read_sql("SELECT * FROM salaries", conn)
title_data = pd.read_sql("SELECT * FROM titles", conn)

# Keeping the last title held by employee for data consistency
title_data_last = title_data.drop_duplicates(["emp_no"], keep = "last")

# %%
# Merging employees and salaries dataframes and choosing to do inner join to remove null values, if any.
salary_emp_merged = pd.merge(employees_data, salary_data, how = "inner", on = "emp_no")
salary_emp_merged
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date salary  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26  60117
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21  65828
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28  40006
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01  40054
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12  78228
# ...        ...         ...        ...       ...    ...         ...    ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12  40000
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27  58058
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21  49597
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13  40000
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30  63707
#
#          from_date     to_date
# 0       1986-06-26  1987-06-26
# ...

# %%
# Merging merged dataframe with salaries to get titles of employees
sal_emp_title_merged = pd.merge(salary_emp_merged, title_data_last, how = "left", on = "emp_no")

# Selecting only the relevent columns 
sal_title = sal_emp_title_merged[["title", "salary"]]
sal_title
# Out:
#                   title salary
# 0       Senior Engineer  60117
# 1                 Staff  65828
# 2       Senior Engineer  40006
# 3       Senior Engineer  40054
# 4                 Staff  78228
# ...                 ...    ...
# 300019         Engineer  40000
# 300020  Senior Engineer  58058
# 300021  Senior Engineer  49597
# 300022            Staff  40000
# 300023         Engineer  63707
#
# [300024 rows x 2 columns]

# %%
# Converting salary data to float
sal_title["salary"] = sal_title["salary"].astype(float)
sal_title.head()
# Out:
# /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              title   salary
# 0  Senior Engineer  60117.0
# 1            Staff  65828.0
# 2  Senior Engineer  40006.0
# 3  Senior Engineer  40054.0
# 4            Staff  78228.0

# %%
# Create a histogram to visualize the most common salary ranges for employees.
sal_title.plot.hist(by = "salary")
plt.title("Most Common Salary Range")
plt.xlabel("Salary USD")

# Printing results
plt.show()

# %%
# Grouping by salary to get average salary per title
sal_group = sal_title.groupby("title")
sal_group_mean = sal_group.mean()

# %%
# Create a bar chart of average salary by title.
sal_group_mean.plot.bar()
plt.title("Average Salary by Title")
plt.xlabel("Job Title")

# Printing results
plt.show()

# %%
# "Search your ID number." You look down at your badge to see that your employee ID number is 499942.
output = sal_emp_title_merged[(sal_emp_title_merged["emp_no"] == 499942)]
output
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date salary  \
# 299966  499942  1963-01-10      April  Foolsday      F  1997-02-10  40000
#
#        from_date_x   to_date_x             title from_date_y   to_date_y
# 299966  1998-03-28  1999-03-28  Technique Leader  1998-03-28  9999-01-01

# %% [markdown]
# ## THANK YOU!
